# %%
#Define Classes
class Team:

    def __init__(self, Country, Matches_played, Matches_won, Matches_drawn, Matches_lost, Goals_for, Goals_against, Points,):
        self.Country = Country
        self.Matches_played = Matches_played
        self.Matches_won = Matches_won
        self.Matches_drawn = Matches_drawn
        self.Matches_lost = Matches_lost
        self.Goals_for = Goals_for
        self.Goals_against = Goals_against
        self.Points = Points
    #Get Team info
    def GetInfo(self):
        infodict = {"Country": self.Country, "MP": self.Matches_played, "MW": self.Matches_won, "MD": self.Matches_drawn, "ML": self.Matches_lost, "GF": self.Goals_for, "GA": self.Goals_against, "GD": (self.Goals_for - self.Goals_against), "Pts": self.Points}
        print(infodict)
#         print("Country:", self.Country, "MP:", self.Matches_played, "MW:", self.Matches_won, "MD:", self.Matches_drawn, "ML:", self.Matches_lost, "GF:", self.Goals_for, "GA:", self.Goals_against, "GD:", (self.Goals_for - self.Goals_against), "Pts:", self.Points)

    def PopPoints(self):
        self.Points = (self.Matches_won * 3) + self.Matches_drawn
    def PopWin(self):
        self.Matches_won = self.Matches_won + 1
        self.Matches_played = self.Matches_played + 1
        self.PopPoints()
    def PopDraw(self):
        self.Matches_drawn = self.Matches_drawn + 1
        self.Matches_played = self.Matches_played + 1
        self.PopPoints()
    def PopLoss(self):
        self.Matches_lost = self.Matches_lost + 1
        self.Matches_played = self.Matches_played + 1
        self.PopPoints()
    def PopGoalsFor(self, a):
        self.Goals_for = self.Goals_for + int(a)
    def PopGoalsAgainst(self, a):
        self.Goals_against = self.Goals_against + int(a)

class Groups:

    def __init__(self, Country, Matches_played, Matches_won, Matches_drawn, Matches_lost, Goals_for, Goals_against, Points,):
        self.Country = Country
        self.Matches_played = Matches_played
        self.Matches_won = Matches_won
        self.Matches_drawn = Matches_drawn
        self.Matches_lost = Matches_lost
        self.Goals_for = Goals_for
        self.Goals_against = Goals_against
        self.Points = Points
        
class GroupA(Groups):
    def GetInfo(self):
        infodict = {"Country": self.Country, "MP": self.Matches_played, "MW": self.Matches_won, "MD": self.Matches_drawn, "ML": self.Matches_lost, "GF": self.Goals_for, "GA": self.Goals_against, "GD": (self.Goals_for - self.Goals_against), "Pts": self.Points}
        print(infodict)
    def PopPoints(self):
        self.Points = (self.Matches_won * 3) + self.Matches_drawn
    def PopWin(self):
        self.Matches_won = self.Matches_won + 1
        self.Matches_played = self.Matches_played + 1
        self.PopPoints()
    def PopDraw(self):
        self.Matches_drawn = self.Matches_drawn + 1
        self.Matches_played = self.Matches_played + 1
        self.PopPoints()
    def PopLoss(self):
        self.Matches_lost = self.Matches_lost + 1
        self.Matches_played = self.Matches_played + 1
        self.PopPoints()
    def PopGoalsFor(self, a):
        self.Goals_for = self.Goals_for + int(a)
    def PopGoalsAgainst(self, a):
        self.Goals_against = self.Goals_against + int(a)

class GroupB(Groups):

    def GetInfo(self):
        infodict = {"Country": self.Country, "MP": self.Matches_played, "MW": self.Matches_won, "MD": self.Matches_drawn, "ML": self.Matches_lost, "GF": self.Goals_for, "GA": self.Goals_against, "GD": (self.Goals_for - self.Goals_against), "Pts": self.Points}
        print(infodict)
    def PopPoints(self):
        self.Points = (self.Matches_won * 3) + self.Matches_drawn
    def PopWin(self):
        self.Matches_won = self.Matches_won + 1
        self.Matches_played = self.Matches_played + 1
        self.PopPoints()
    def PopDraw(self):
        self.Matches_drawn = self.Matches_drawn + 1
        self.Matches_played = self.Matches_played + 1
        self.PopPoints()
    def PopLoss(self):
        self.Matches_lost = self.Matches_lost + 1
        self.Matches_played = self.Matches_played + 1
        self.PopPoints()
    def PopGoalsFor(self, a):
        self.Goals_for = self.Goals_for + int(a)
    def PopGoalsAgainst(self, a):
        self.Goals_against = self.Goals_against + int(a)

class GroupC(Groups):

    def GetInfo(self):
        infodict = {"Country": self.Country, "MP": self.Matches_played, "MW": self.Matches_won, "MD": self.Matches_drawn, "ML": self.Matches_lost, "GF": self.Goals_for, "GA": self.Goals_against, "GD": (self.Goals_for - self.Goals_against), "Pts": self.Points}
        print(infodict)
    def PopPoints(self):
        self.Points = (self.Matches_won * 3) + self.Matches_drawn
    def PopWin(self):
        self.Matches_won = self.Matches_won + 1
        self.Matches_played = self.Matches_played + 1
        self.PopPoints()
    def PopDraw(self):
        self.Matches_drawn = self.Matches_drawn + 1
        self.Matches_played = self.Matches_played + 1
        self.PopPoints()
    def PopLoss(self):
        self.Matches_lost = self.Matches_lost + 1
        self.Matches_played = self.Matches_played + 1
        self.PopPoints()
    def PopGoalsFor(self, a):
        self.Goals_for = self.Goals_for + int(a)
    def PopGoalsAgainst(self, a):
        self.Goals_against = self.Goals_against + int(a)

class GroupD(Groups):

    def GetInfo(self):
        infodict = {"Country": self.Country, "MP": self.Matches_played, "MW": self.Matches_won, "MD": self.Matches_drawn, "ML": self.Matches_lost, "GF": self.Goals_for, "GA": self.Goals_against, "GD": (self.Goals_for - self.Goals_against), "Pts": self.Points}
        print(infodict)
    def PopPoints(self):
        self.Points = (self.Matches_won * 3) + self.Matches_drawn
    def PopWin(self):
        self.Matches_won = self.Matches_won + 1
        self.Matches_played = self.Matches_played + 1
        self.PopPoints()
    def PopDraw(self):
        self.Matches_drawn = self.Matches_drawn + 1
        self.Matches_played = self.Matches_played + 1
        self.PopPoints()
    def PopLoss(self):
        self.Matches_lost = self.Matches_lost + 1
        self.Matches_played = self.Matches_played + 1
        self.PopPoints()
    def PopGoalsFor(self, a):
        self.Goals_for = self.Goals_for + int(a)
    def PopGoalsAgainst(self, a):
        self.Goals_against = self.Goals_against + int(a)

class GroupE(Groups):

    def GetInfo(self):
        infodict = {"Country": self.Country, "MP": self.Matches_played, "MW": self.Matches_won, "MD": self.Matches_drawn, "ML": self.Matches_lost, "GF": self.Goals_for, "GA": self.Goals_against, "GD": (self.Goals_for - self.Goals_against), "Pts": self.Points}
        print(infodict)
    def PopPoints(self):
        self.Points = (self.Matches_won * 3) + self.Matches_drawn
    def PopWin(self):
        self.Matches_won = self.Matches_won + 1
        self.Matches_played = self.Matches_played + 1
        self.PopPoints()
    def PopDraw(self):
        self.Matches_drawn = self.Matches_drawn + 1
        self.Matches_played = self.Matches_played + 1
        self.PopPoints()
    def PopLoss(self):
        self.Matches_lost = self.Matches_lost + 1
        self.Matches_played = self.Matches_played + 1
        self.PopPoints()
    def PopGoalsFor(self, a):
        self.Goals_for = self.Goals_for + int(a)
    def PopGoalsAgainst(self, a):
        self.Goals_against = self.Goals_against + int(a)

class GroupF(Groups):

    def GetInfo(self):
        infodict = {"Country": self.Country, "MP": self.Matches_played, "MW": self.Matches_won, "MD": self.Matches_drawn, "ML": self.Matches_lost, "GF": self.Goals_for, "GA": self.Goals_against, "GD": (self.Goals_for - self.Goals_against), "Pts": self.Points}
        print(infodict)
    def PopPoints(self):
        self.Points = (self.Matches_won * 3) + self.Matches_drawn
    def PopWin(self):
        self.Matches_won = self.Matches_won + 1
        self.Matches_played = self.Matches_played + 1
        self.PopPoints()
    def PopDraw(self):
        self.Matches_drawn = self.Matches_drawn + 1
        self.Matches_played = self.Matches_played + 1
        self.PopPoints()
    def PopLoss(self):
        self.Matches_lost = self.Matches_lost + 1
        self.Matches_played = self.Matches_played + 1
        self.PopPoints()
    def PopGoalsFor(self, a):
        self.Goals_for = self.Goals_for + int(a)
    def PopGoalsAgainst(self, a):
        self.Goals_against = self.Goals_against + int(a)

class GroupG(Groups):

    def GetInfo(self):
        infodict = {"Country": self.Country, "MP": self.Matches_played, "MW": self.Matches_won, "MD": self.Matches_drawn, "ML": self.Matches_lost, "GF": self.Goals_for, "GA": self.Goals_against, "GD": (self.Goals_for - self.Goals_against), "Pts": self.Points}
        print(infodict)
    def PopPoints(self):
        self.Points = (self.Matches_won * 3) + self.Matches_drawn
    def PopWin(self):
        self.Matches_won = self.Matches_won + 1
        self.Matches_played = self.Matches_played + 1
        self.PopPoints()
    def PopDraw(self):
        self.Matches_drawn = self.Matches_drawn + 1
        self.Matches_played = self.Matches_played + 1
        self.PopPoints()
    def PopLoss(self):
        self.Matches_lost = self.Matches_lost + 1
        self.Matches_played = self.Matches_played + 1
        self.PopPoints()
    def PopGoalsFor(self, a):
        self.Goals_for = self.Goals_for + int(a)
    def PopGoalsAgainst(self, a):
        self.Goals_against = self.Goals_against + int(a)

class GroupH(Groups):

    def GetInfo(self):
        infodict = {"Country": self.Country, "MP": self.Matches_played, "MW": self.Matches_won, "MD": self.Matches_drawn, "ML": self.Matches_lost, "GF": self.Goals_for, "GA": self.Goals_against, "GD": (self.Goals_for - self.Goals_against), "Pts": self.Points}
        print(infodict)
    def PopPoints(self):
        self.Points = (self.Matches_won * 3) + self.Matches_drawn
    def PopWin(self):
        self.Matches_won = self.Matches_won + 1
        self.Matches_played = self.Matches_played + 1
        self.PopPoints()
    def PopDraw(self):
        self.Matches_drawn = self.Matches_drawn + 1
        self.Matches_played = self.Matches_played + 1
        self.PopPoints()
    def PopLoss(self):
        self.Matches_lost = self.Matches_lost + 1
        self.Matches_played = self.Matches_played + 1
        self.PopPoints()
    def PopGoalsFor(self, a):
        self.Goals_for = self.Goals_for + int(a)
    def PopGoalsAgainst(self, a):
        self.Goals_against = self.Goals_against + int(a)

# def wcinit():
Qatar = Team("Qatar", 0, 0, 0, 0, 0, 0, 0)
Germany = Team("Germany", 0, 0, 0, 0, 0, 0, 0)
Denmark = Team("Denmark", 0, 0, 0, 0, 0, 0, 0)
Brazil = Team("Brazil", 0, 0, 0, 0, 0, 0, 0)
France = Team("France", 0, 0, 0, 0, 0, 0, 0)
Belgium = Team("Belgium", 0, 0, 0, 0, 0, 0, 0)
Croatia = Team("Croatia", 0, 0, 0, 0, 0, 0, 0)
Spain = Team("Spain", 0, 0, 0, 0, 0, 0, 0)
Serbia = Team("Serbia", 0, 0, 0, 0, 0, 0, 0)
England = Team("England", 0, 0, 0, 0, 0, 0, 0)
Switzerland = Team("Switzerland", 0, 0, 0, 0, 0, 0, 0)
Netherlands = Team("Netherlands", 0, 0, 0, 0, 0, 0, 0)
Argentina = Team("Argentina", 0, 0, 0, 0, 0, 0, 0)
Iran = Team("Iran", 0, 0, 0, 0, 0, 0, 0)
South_Korea = Team("South Korea", 0, 0, 0, 0, 0, 0, 0)
Japan = Team("Japan", 0, 0, 0, 0, 0, 0, 0)
Saudi_Arabia = Team("Saudi Arabia", 0, 0, 0, 0, 0, 0, 0)
Ecuador = Team("Ecuador", 0, 0, 0, 0, 0, 0, 0)
Uruguay = Team("Uruguay", 0, 0, 0, 0, 0, 0, 0)
Canada = Team("Canada", 0, 0, 0, 0, 0, 0, 0)
Ghana = Team("Ghana", 0, 0, 0, 0, 0, 0, 0)
Senegal = Team("Senegal", 0, 0, 0, 0, 0, 0, 0)
Portugal = Team("Portugal", 0, 0, 0, 0, 0, 0, 0)
Poland = Team("Poland", 0, 0, 0, 0, 0, 0, 0)
Tunisia = Team("Tunisia", 0, 0, 0, 0, 0, 0, 0)
Morocco = Team("Morocco", 0, 0, 0, 0, 0, 0, 0)
Cameroon = Team("Cameroon", 0, 0, 0, 0, 0, 0, 0)
USA = Team("USA", 0, 0, 0, 0, 0, 0, 0)
Mexico = Team("Mexico", 0, 0, 0, 0, 0, 0, 0)
Wales = Team("Wales", 0, 0, 0, 0, 0, 0, 0)
Australia = Team("Australia", 0, 0, 0, 0, 0, 0, 0)
Costa_Rica = Team("Costa Rica", 0, 0, 0, 0, 0, 0, 0)

# def groupA_init():
Qatar = GroupA("Qatar", 0, 0, 0, 0, 0, 0, 0)
Netherlands = GroupA("Netherlands", 0, 0, 0, 0, 0, 0, 0)
Senegal = GroupA("Senegal", 0, 0, 0, 0, 0, 0, 0)
Ecuador = GroupA("Ecuador", 0, 0, 0, 0, 0, 0, 0)

# def groupB_init():
Wales = GroupB("Wales", 0, 0, 0, 0, 0, 0, 0)
USA = GroupB("USA", 0, 0, 0, 0, 0, 0, 0)
England = GroupB("England", 0, 0, 0, 0, 0, 0, 0)
Iran = GroupB("Iran", 0, 0, 0, 0, 0, 0, 0)

# def groupC_init():
Mexico = GroupC("Mexico", 0, 0, 0, 0, 0, 0, 0)
Poland = GroupC("Poland", 0, 0, 0, 0, 0, 0, 0)
Argentina = GroupC("Argentina", 0, 0, 0, 0, 0, 0, 0)
Saudi_Arabia = GroupC("Saudi Arabia", 0, 0, 0, 0, 0, 0, 0)

# def groupD_init():
France = GroupD("France", 0, 0, 0, 0, 0, 0, 0)
Australia = GroupD("Australia", 0, 0, 0, 0, 0, 0, 0)
Tunisia = GroupD("Tunisia", 0, 0, 0, 0, 0, 0, 0)
Denmark = GroupD("Denmark", 0, 0, 0, 0, 0, 0, 0)
    
# def groupE_init():
Japan = GroupE("Japan", 0, 0, 0, 0, 0, 0, 0)
Spain = GroupE("Spain", 0, 0, 0, 0, 0, 0, 0)
Germany = GroupE("Germany", 0, 0, 0, 0, 0, 0, 0)
Costa_Rica = GroupE("Costa Rica", 0, 0, 0, 0, 0, 0, 0)

# def groupF_init():
Morocco = GroupF("Morocco", 0, 0, 0, 0, 0, 0, 0)
Belgium = GroupF("Belgium", 0, 0, 0, 0, 0, 0, 0)
Croatia = GroupF("Croatia", 0, 0, 0, 0, 0, 0, 0)
Canada = GroupF("Canada", 0, 0, 0, 0, 0, 0, 0)
    
# def groupG_init():
Brazil = GroupG("Brazil", 0, 0, 0, 0, 0, 0, 0)
Switzerland = GroupG("Switzerland", 0, 0, 0, 0, 0, 0, 0)
Cameroon = GroupG("Cameroon", 0, 0, 0, 0, 0, 0, 0)
Serbia = GroupG("Serbia", 0, 0, 0, 0, 0, 0, 0)

# def groupH_init():
Portugal = GroupH("Portugal", 0, 0, 0, 0, 0, 0, 0)
South_Korea = GroupH("South Korea", 0, 0, 0, 0, 0, 0, 0)
Uruguay = GroupH("Uruguay", 0, 0, 0, 0, 0, 0, 0)
Ghana = GroupH("Ghana", 0, 0, 0, 0, 0, 0, 0)
    
# wcinit()
# groupA_init()
# groupB_init()
# groupC_init()
# groupD_init()
# groupE_init()
# groupF_init()
# groupG_init()
# groupH_init()

# def dispinfo():

print("GroupA:")
Qatar.GetInfo()
Netherlands.GetInfo()
Senegal.GetInfo()
Ecuador.GetInfo()

print("GroupB:")
Wales.GetInfo()
USA.GetInfo()
England.GetInfo()
Iran.GetInfo()

print("GroupC:")
Mexico.GetInfo()
Poland.GetInfo()
Argentina.GetInfo()
Saudi_Arabia.GetInfo()

print("GroupD:")
France.GetInfo()
Australia.GetInfo()
Tunisia.GetInfo()
Denmark.GetInfo()

print("GroupE:")
Japan.GetInfo()
Spain.GetInfo()
Germany.GetInfo()
Costa_Rica.GetInfo()

print("GroupF:")
Morocco.GetInfo()
Belgium.GetInfo()
Croatia.GetInfo()
Canada.GetInfo()

print("GroupG:")
Brazil.GetInfo()
Switzerland.GetInfo()
Cameroon.GetInfo()
Serbia.GetInfo()

print("GroupH:")
Portugal.GetInfo()
South_Korea.GetInfo()
Uruguay.GetInfo()
Ghana.GetInfo()

def round_one(a, b):
#     a = str(a.Country)
#     b = str(b.Country)
    print("This Game is", a.Country, "vs", b.Country)
    print("How many goals did", a.Country, "score for the game", a.Country, "vs", b.Country, ":")
    x = input("Enter score here:")
    print("How many goals did", b.Country, "score for the game", a.Country, "vs", b.Country, ":")
    y = input("Enter score here:")
    if y < x:
        print(a.Country, "won the match")
        a.PopWin()
        b.PopLoss()
        a.PopGoalsFor(x)
        a.PopGoalsAgainst(y)
        b.PopGoalsFor(y)
        b.PopGoalsAgainst(x)
    else:
        if x == y:
            print(a.Country, "vs", b.Country, "was a draw game")
            a.PopDraw()
            b.PopDraw()
            a.PopGoalsFor(x)
            a.PopGoalsAgainst(y)
            b.PopGoalsFor(y)
            b.PopGoalsAgainst(x)
        else:
            print(b.Country, "won the match")
            b.PopWin()
            a.PopLoss()
            a.PopGoalsFor(x)
            a.PopGoalsAgainst(y)
            b.PopGoalsFor(y)
            b.PopGoalsAgainst(x)

import time
def round_one_games():
    print("This is the first round of Games for the group stage of The World Cup")
    time.sleep(3)
    round_one(Qatar, Ecuador)
    round_one(England, Iran)
    round_one(Senegal, Netherlands)
    round_one(USA, Wales)
    round_one(Argentina, Saudi_Arabia)
    round_one(Denmark, Tunisia)
    round_one(Mexico, Poland)
    round_one(France, Australia)
    round_one(Morocco, Croatia)
    round_one(Germany, Japan)
    round_one(Spain, Costa_Rica)
    round_one(Belgium, Canada)
    round_one(Switzerland, Cameroon)
    round_one(Uruguay, South_Korea)
    round_one(Portugal, Ghana)
    round_one(Brazil, Serbia)

round_one_games()  

print("Results after Round One:")
time.sleep(5)

print("GroupA:")
Qatar.GetInfo()
Netherlands.GetInfo()
Senegal.GetInfo()
Ecuador.GetInfo()

print("GroupB:")
Wales.GetInfo()
USA.GetInfo()
England.GetInfo()
Iran.GetInfo()

print("GroupC:")
Mexico.GetInfo()
Poland.GetInfo()
Argentina.GetInfo()
Saudi_Arabia.GetInfo()

print("GroupD:")
France.GetInfo()
Australia.GetInfo()
Tunisia.GetInfo()
Denmark.GetInfo()

print("GroupE:")
Japan.GetInfo()
Spain.GetInfo()
Germany.GetInfo()
Costa_Rica.GetInfo()

print("GroupF:")
Morocco.GetInfo()
Belgium.GetInfo()
Croatia.GetInfo()
Canada.GetInfo()

print("GroupG:")
Brazil.GetInfo()
Switzerland.GetInfo()
Cameroon.GetInfo()
Serbia.GetInfo()

print("GroupH:")
Portugal.GetInfo()
South_Korea.GetInfo()
Uruguay.GetInfo()
Ghana.GetInfo()
# Qatar.GetInfo()
# Ecuador.GetInfo()

# dispinfo()

# import re
# f = open("wclist.txt", "r")
# wcdata = []*0
# for i in f:
#     i = re.split('\n', i)
#     wcdata.append(i[0])
# f.close()
# def func(a):
#     a.GetInfo()
# wcdata_one = wcdata
# for i in wcdata:
#     func(i)


# x = input("How many goals did Cameroun score for the game Cameroun vs Switzerland:")
# y = input("How many goals did Switzerland score for the game Cameroun vs Switzerland:")
# if y < x:
#     print("Cameroun won the match")
#     cameroon.PopWin()
#     switzerland.PopLoss()
#     cameroon.PopGoalsFor(x)
#     cameroon.PopGoalsAgainst(y)
#     switzerland.PopGoalsFor(y)
#     switzerland.PopGoalsAgainst(x)
# else:
#     if x == y:
#         print("Cameroun vs Switzerland was a draw game")
#         cameroon.PopDraw()
#         switzerland.PopDraw()
#         cameroon.PopGoalsFor(x)
#         cameroon.PopGoalsAgainst(y)
#         switzerland.PopGoalsFor(y)
#         switzerland.PopGoalsAgainst(x)
#     else:
#         print("Switzerland won the match")
#         switzerland.PopWin()
#         cameroon.PopLoss()
#         cameroon.PopGoalsFor(x)
#         cameroon.PopGoalsAgainst(y)
#         switzerland.PopGoalsFor(y)
#         switzerland.PopGoalsAgainst(x)
# cameroon.GetInfo()
# switzerland.GetInfo()




# class Round16:
